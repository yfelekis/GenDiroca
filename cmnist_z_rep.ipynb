# %%
import os, sys

# TODO: change this to the actual absolute path
NCA_ROOT = "/Users/giofelekis/Desktop/NeuralCausalAbstractions"

assert os.path.isdir(NCA_ROOT), f"{NCA_ROOT} not found. Fix the path."

# Put their repo at the *front* of sys.path when we want to import their code
sys.path.insert(0, NCA_ROOT)

print("Using NCA repo at:", NCA_ROOT)
print("First few entries in sys.path:")
print(sys.path[:5])
# Out:
# Using NCA repo at: /Users/giofelekis/Desktop/NeuralCausalAbstractions
# First few entries in sys.path:
# ['/Users/giofelekis/Desktop/NeuralCausalAbstractions', '/Users/giofelekis/opt/anaconda3/envs/erica/lib/python312.zip', '/Users/giofelekis/opt/anaconda3/envs/erica/lib/python3.12', '/Users/giofelekis/opt/anaconda3/envs/erica/lib/python3.12/lib-dynload', '']

# %%
import subprocess, textwrap, sys, os

req_path = os.path.join(NCA_ROOT, "requirements.txt")
print("Requirements file:", req_path)

subprocess.run(
    [sys.executable, "-m", "pip", "install", "-r", req_path],
    check=False
)
# Out:
# Requirements file: /Users/giofelekis/Desktop/NeuralCausalAbstractions/requirements.txt
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '/Users/giofelekis/Desktop/NeuralCausalAbstractions/requirements.txt'
# CompletedProcess(args=['/Users/giofelekis/opt/anaconda3/envs/erica/bin/python', '-m', 'pip', 'install', '-r', '/Users/giofelekis/Desktop/NeuralCausalAbstractions/requirements.txt'], returncode=1)

# %%
# These should come from NeuralCausalAbstractions
from src.datagen.color_mnist import ColorMNISTDataGenerator
from src.scm.repr_nn.representation_nn import RepresentationalNN

print("Imports from NCA successful ✅")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # These should come from NeuralCausalAbstractions
# ----> 2 from src.datagen.color_mnist import ColorMNISTDataGenerator
#       3 from src.scm.repr_nn.representation_nn import RepresentationalNN
#       5 print("Imports from NCA successful ✅")
#
# File ~/Desktop/NeuralCausalAbstractions/src/datagen/__init__.py:3
#       1 from src.datagen.scm_datagen import SCMDataset, SCMDataTypes, SCMDataGenerator
#       2 from src.datagen.img_transforms import get_transform
# ----> 3 from src.datagen.mnist_bd import MNISTDataGenerator
#       4 from src.datagen.color_mnist import ColorMNISTDataGenerator
#       5 from src.datagen.bmi import BMIDataGenerator
#
# File ~/Desktop/NeuralCausalAbstractions/src/datagen/mnist_bd.py:3
#       1 import numpy as np
#       2 import torch as T
# ...
